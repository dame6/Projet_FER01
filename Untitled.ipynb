# %%
from __future__ import print_function
import argparse
import numpy  as np
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms
from data_loaders import Plain_Dataset, eval_data_dataloader
from deep_emotion import Deep_Emotion
from generate_data import Generate_data

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

def Train(epochs,train_loader,val_loader,criterion,optmizer,device):
    '''
    Training Loop
    '''
    print("===================================Start Training===================================")
    for e in range(epochs):
        train_loss = 0
        validation_loss = 0
        train_correct = 0
        val_correct = 0
        # Train the model  #
        net.train()
        for data, labels in train_loader:
            data, labels = data.to(device), labels.to(device)
            optmizer.zero_grad()
            outputs = net(data)
            loss = criterion(outputs,labels)
            loss.backward()
            optmizer.step()
            train_loss += loss.item()
            _, preds = torch.max(outputs,1)
            train_correct += torch.sum(preds == labels.data)

        #validate the model#
        net.eval()
        for data,labels in val_loader:
            data, labels = data.to(device), labels.to(device)
            val_outputs = net(data)
            val_loss = criterion(val_outputs, labels)
            validation_loss += val_loss.item()
            _, val_preds = torch.max(val_outputs,1)
            val_correct += torch.sum(val_preds == labels.data)

        train_loss = train_loss/len(train_dataset)
        train_acc = train_correct.double() / len(train_dataset)
        validation_loss =  validation_loss / len(validation_dataset)
        val_acc = val_correct.double() / len(validation_dataset)
        print('Epoch: {} \tTraining Loss: {:.8f} \tValidation Loss {:.8f} \tTraining Accuracy {:.3f}% \tValidation Accuracy {:.3f}%'
                                                           .format(e+1, train_loss,validation_loss,train_acc * 100, val_acc*100))

    torch.save(net.state_dict(),'deep_emotion-{}-{}-{}.pt'.format(epochs,batchsize,lr))
    print("===================================Training Finished===================================")

"""
if __name__ == '__main__':
    parser = argparse.ArgumentParser(description="Configuration of setup and training process")
    parser.add_argument('-s', '--setup', type=bool, help='setup the dataset for the first time')
    parser.add_argument('-d', '--data', type=str,required= True,
                               help='data folder that contains data files that downloaded from kaggle (train.csv and test.csv)')
    parser.add_argument('-hparams', '--hyperparams', type=bool,
                               help='True when changing the hyperparameters e.g (batch size, LR, num. of epochs)')
    parser.add_argument('-e', '--epochs', type= int, help= 'number of epochs')
    parser.add_argument('-lr', '--learning_rate', type= float, help= 'value of learning rate')
    parser.add_argument('-bs', '--batch_size', type= int, help= 'training/validation batch size')
    parser.add_argument('-t', '--train', type=bool, help='True when training')
    args = parser.parse_args()

    if args.setup :"""
generate_dataset = Generate_data("data//")
generate_dataset.split_test()
generate_dataset.save_images('train')
#generate_dataset.save_images('finaltest')
#generate_dataset.save_images('test')
generate_dataset.save_images('val')

    #if args.hyperparams:
        #epochs = args.epochs
        #lr = args.learning_rate
        #batchsize = args.batch_size
    #else :
   
epochs = 100
lr = 0.005
batchsize = 128

   # if args.train:
net = Deep_Emotion()
net.to(device)
print("Model archticture: ", net)
traincsv_file = 'data'+'/'+'train.csv'
validationcsv_file = 'data'+'/'+'val.csv'
train_img_dir = 'data'+'/'+'train/'
validation_img_dir = 'data'+'/'+'val/'

transformation= transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,),(0.5,))])
train_dataset= Plain_Dataset(csv_file=traincsv_file, img_dir = train_img_dir, datatype = 'train', transform = transformation)
validation_dataset= Plain_Dataset(csv_file=validationcsv_file, img_dir = validation_img_dir, datatype = 'val', transform = transformation)
train_loader= DataLoader(train_dataset,batch_size=batchsize,shuffle = True,num_workers=0)
val_loader= DataLoader(validation_dataset,batch_size=batchsize,shuffle = True,num_workers=0)

criterion= nn.CrossEntropyLoss()
optmizer= optim.Adam(net.parameters(),lr= lr)
Train(epochs, train_loader, val_loader, criterion, optmizer, device)
# Out:
# Done splitting the test file into validation & final test dddddddddd file
# 100%|███████████████████████████████████████████████████████████████████████████| 25121/25121 [02:33<00:00, 163.93it/s]
# Done saving data///train data
# 100%|█████████████████████████████████████████████████████████████████████████████| 3588/3588 [00:13<00:00, 259.59it/s]
# Done saving data///val data
# Model archticture:  Deep_Emotion(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=810, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=7, bias=True)
#   (localization): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(7, 7), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(8, 10, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#   )
#   (fc_loc): Sequential(
#     (0): Linear(in_features=640, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=6, bias=True)
#   )
# )
# ===================================Start Training===================================
# C:\Users\dameb\anaconda3\lib\site-packages\torch\nn\functional.py:4404: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# C:\Users\dameb\anaconda3\lib\site-packages\torch\nn\functional.py:4343: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# Epoch: 1 	Training Loss: 0.01351638 	Validation Loss 0.01354882 	Training Accuracy 30.254% 	Validation Accuracy 32.915%
# Epoch: 2 	Training Loss: 0.01258198 	Validation Loss 0.01270578 	Training Accuracy 37.073% 	Validation Accuracy 38.489%
# Epoch: 3 	Training Loss: 0.01199971 	Validation Loss 0.01259451 	Training Accuracy 40.233% 	Validation Accuracy 38.907%
# Epoch: 4 	Training Loss: 0.01159493 	Validation Loss 0.01303630 	Training Accuracy 42.391% 	Validation Accuracy 36.343%
# Epoch: 5 	Training Loss: 0.01124556 	Validation Loss 0.01184862 	Training Accuracy 44.349% 	Validation Accuracy 42.531%
# Epoch: 6 	Training Loss: 0.01104675 	Validation Loss 0.01181845 	Training Accuracy 45.134% 	Validation Accuracy 43.283%
# Epoch: 7 	Training Loss: 0.01087241 	Validation Loss 0.01149986 	Training Accuracy 46.571% 	Validation Accuracy 44.677%
# Epoch: 8 	Training Loss: 0.01068204 	Validation Loss 0.01137335 	Training Accuracy 47.028% 	Validation Accuracy 45.178%
# Epoch: 9 	Training Loss: 0.01062400 	Validation Loss 0.01152227 	Training Accuracy 47.729% 	Validation Accuracy 45.624%
# Epoch: 10 	Training Loss: 0.01049356 	Validation Loss 0.01136614 	Training Accuracy 48.215% 	Validation Accuracy 45.095%
# Epoch: 11 	Training Loss: 0.01047292 	Validation Loss 0.01143526 	Training Accuracy 48.438% 	Validation Accuracy 44.537%
# Epoch: 12 	Training Loss: 0.01039095 	Validation Loss 0.01145227 	Training Accuracy 48.836% 	Validation Accuracy 47.101%
# Epoch: 13 	Training Loss: 0.01033833 	Validation Loss 0.01129775 	Training Accuracy 49.266% 	Validation Accuracy 45.959%
# Epoch: 14 	Training Loss: 0.01026944 	Validation Loss 0.01135781 	Training Accuracy 49.500% 	Validation Accuracy 45.541%
# Epoch: 15 	Training Loss: 0.01021240 	Validation Loss 0.01129141 	Training Accuracy 49.779% 	Validation Accuracy 44.231%
# Epoch: 16 	Training Loss: 0.01017046 	Validation Loss 0.01152848 	Training Accuracy 50.014% 	Validation Accuracy 47.965%
# Epoch: 17 	Training Loss: 0.01009395 	Validation Loss 0.01119487 	Training Accuracy 50.631% 	Validation Accuracy 46.154%
# Epoch: 18 	Training Loss: 0.01010582 	Validation Loss 0.01105934 	Training Accuracy 50.651% 	Validation Accuracy 46.683%
# Epoch: 19 	Training Loss: 0.01002454 	Validation Loss 0.01112751 	Training Accuracy 50.973% 	Validation Accuracy 46.405%
# Epoch: 20 	Training Loss: 0.01002999 	Validation Loss 0.01126861 	Training Accuracy 50.623% 	Validation Accuracy 45.736%
# Epoch: 21 	Training Loss: 0.01004013 	Validation Loss 0.01124133 	Training Accuracy 50.993% 	Validation Accuracy 46.098%
# Epoch: 22 	Training Loss: 0.01000614 	Validation Loss 0.01122780 	Training Accuracy 51.188% 	Validation Accuracy 46.098%
# Epoch: 23 	Training Loss: 0.00994766 	Validation Loss 0.01092075 	Training Accuracy 51.053% 	Validation Accuracy 46.516%
# Epoch: 24 	Training Loss: 0.00992216 	Validation Loss 0.01105191 	Training Accuracy 51.252% 	Validation Accuracy 47.269%
# Epoch: 25 	Training Loss: 0.00994380 	Validation Loss 0.01100775 	Training Accuracy 51.523% 	Validation Accuracy 47.826%
# Epoch: 26 	Training Loss: 0.00988154 	Validation Loss 0.01095192 	Training Accuracy 51.964% 	Validation Accuracy 47.157%
# Epoch: 27 	Training Loss: 0.00987211 	Validation Loss 0.01109860 	Training Accuracy 51.674% 	Validation Accuracy 47.074%
# Epoch: 28 	Training Loss: 0.00981385 	Validation Loss 0.01129713 	Training Accuracy 52.319% 	Validation Accuracy 45.652%
# Epoch: 29 	Training Loss: 0.00978055 	Validation Loss 0.01080925 	Training Accuracy 52.000% 	Validation Accuracy 48.551%
# Epoch: 30 	Training Loss: 0.00983841 	Validation Loss 0.01085555 	Training Accuracy 52.076% 	Validation Accuracy 47.297%
# Epoch: 31 	Training Loss: 0.00981989 	Validation Loss 0.01126291 	Training Accuracy 52.084% 	Validation Accuracy 48.356%
# Epoch: 32 	Training Loss: 0.00980535 	Validation Loss 0.01088191 	Training Accuracy 52.207% 	Validation Accuracy 48.467%
# Epoch: 33 	Training Loss: 0.00975214 	Validation Loss 0.01102207 	Training Accuracy 52.864% 	Validation Accuracy 47.826%
# Epoch: 34 	Training Loss: 0.00978479 	Validation Loss 0.01087972 	Training Accuracy 52.355% 	Validation Accuracy 47.074%
# Epoch: 35 	Training Loss: 0.00976000 	Validation Loss 0.01089463 	Training Accuracy 52.721% 	Validation Accuracy 46.990%
# Epoch: 36 	Training Loss: 0.00976483 	Validation Loss 0.01090995 	Training Accuracy 52.685% 	Validation Accuracy 48.188%
# Epoch: 37 	Training Loss: 0.00969707 	Validation Loss 0.01065440 	Training Accuracy 52.745% 	Validation Accuracy 47.492%
# Epoch: 38 	Training Loss: 0.00964856 	Validation Loss 0.01101699 	Training Accuracy 53.039% 	Validation Accuracy 47.938%
# Epoch: 39 	Training Loss: 0.00968618 	Validation Loss 0.01107232 	Training Accuracy 52.589% 	Validation Accuracy 47.687%
# Epoch: 40 	Training Loss: 0.00964989 	Validation Loss 0.01087656 	Training Accuracy 52.645% 	Validation Accuracy 47.965%
# Epoch: 41 	Training Loss: 0.00968069 	Validation Loss 0.01124568 	Training Accuracy 53.139% 	Validation Accuracy 47.687%
# Epoch: 42 	Training Loss: 0.00960862 	Validation Loss 0.01111724 	Training Accuracy 53.362% 	Validation Accuracy 47.297%
# Epoch: 43 	Training Loss: 0.00965501 	Validation Loss 0.01090772 	Training Accuracy 52.836% 	Validation Accuracy 47.324%
# Epoch: 44 	Training Loss: 0.00964602 	Validation Loss 0.01096438 	Training Accuracy 52.872% 	Validation Accuracy 48.049%
# Epoch: 45 	Training Loss: 0.00960708 	Validation Loss 0.01110581 	Training Accuracy 53.294% 	Validation Accuracy 48.746%
# Epoch: 46 	Training Loss: 0.00962048 	Validation Loss 0.01082194 	Training Accuracy 52.996% 	Validation Accuracy 47.687%
# Epoch: 47 	Training Loss: 0.00959252 	Validation Loss 0.01076888 	Training Accuracy 53.449% 	Validation Accuracy 48.133%
# Epoch: 48 	Training Loss: 0.00959993 	Validation Loss 0.01109153 	Training Accuracy 52.832% 	Validation Accuracy 48.300%
# Epoch: 49 	Training Loss: 0.00953794 	Validation Loss 0.01093174 	Training Accuracy 53.915% 	Validation Accuracy 47.631%
# Epoch: 50 	Training Loss: 0.00951995 	Validation Loss 0.01074371 	Training Accuracy 53.310% 	Validation Accuracy 47.882%
# Epoch: 51 	Training Loss: 0.00955299 	Validation Loss 0.01080767 	Training Accuracy 53.489% 	Validation Accuracy 49.359%
# Epoch: 52 	Training Loss: 0.00954524 	Validation Loss 0.01104228 	Training Accuracy 53.792% 	Validation Accuracy 47.352%
# Epoch: 53 	Training Loss: 0.00947056 	Validation Loss 0.01099566 	Training Accuracy 53.971% 	Validation Accuracy 46.767%
# Epoch: 54 	Training Loss: 0.00954213 	Validation Loss 0.01069393 	Training Accuracy 53.545% 	Validation Accuracy 47.965%
# Epoch: 55 	Training Loss: 0.00950730 	Validation Loss 0.01098166 	Training Accuracy 53.656% 	Validation Accuracy 48.774%
# Epoch: 56 	Training Loss: 0.00952971 	Validation Loss 0.01119178 	Training Accuracy 53.843% 	Validation Accuracy 47.993%
# Epoch: 57 	Training Loss: 0.00946195 	Validation Loss 0.01086099 	Training Accuracy 53.979% 	Validation Accuracy 48.021%
# Epoch: 58 	Training Loss: 0.00951099 	Validation Loss 0.01100515 	Training Accuracy 53.696% 	Validation Accuracy 47.269%
# Epoch: 59 	Training Loss: 0.00951230 	Validation Loss 0.01047206 	Training Accuracy 54.062% 	Validation Accuracy 48.634%
# Epoch: 60 	Training Loss: 0.00947795 	Validation Loss 0.01070258 	Training Accuracy 54.078% 	Validation Accuracy 47.520%
# Epoch: 61 	Training Loss: 0.00947267 	Validation Loss 0.01100523 	Training Accuracy 54.249% 	Validation Accuracy 48.244%
# Epoch: 62 	Training Loss: 0.00955936 	Validation Loss 0.01079041 	Training Accuracy 53.581% 	Validation Accuracy 49.359%
# Epoch: 63 	Training Loss: 0.00945395 	Validation Loss 0.01092346 	Training Accuracy 54.333% 	Validation Accuracy 47.938%
# Epoch: 64 	Training Loss: 0.00941533 	Validation Loss 0.01111978 	Training Accuracy 53.732% 	Validation Accuracy 47.492%
# Epoch: 65 	Training Loss: 0.00944486 	Validation Loss 0.01062954 	Training Accuracy 54.070% 	Validation Accuracy 48.300%
# Epoch: 66 	Training Loss: 0.00948033 	Validation Loss 0.01088304 	Training Accuracy 53.863% 	Validation Accuracy 48.885%
# Epoch: 67 	Training Loss: 0.00941066 	Validation Loss 0.01117907 	Training Accuracy 54.484% 	Validation Accuracy 48.272%
# Epoch: 68 	Training Loss: 0.00941433 	Validation Loss 0.01128468 	Training Accuracy 54.054% 	Validation Accuracy 47.520%
# Epoch: 69 	Training Loss: 0.00939537 	Validation Loss 0.01096646 	Training Accuracy 54.663% 	Validation Accuracy 47.938%
# Epoch: 70 	Training Loss: 0.00941592 	Validation Loss 0.01083000 	Training Accuracy 54.512% 	Validation Accuracy 48.216%
# Epoch: 71 	Training Loss: 0.00938887 	Validation Loss 0.01103406 	Training Accuracy 54.866% 	Validation Accuracy 47.436%
# Epoch: 72 	Training Loss: 0.00940451 	Validation Loss 0.01132232 	Training Accuracy 54.612% 	Validation Accuracy 48.746%
# Epoch: 73 	Training Loss: 0.00938351 	Validation Loss 0.01097964 	Training Accuracy 54.588% 	Validation Accuracy 47.464%
# Epoch: 74 	Training Loss: 0.00938394 	Validation Loss 0.01087142 	Training Accuracy 54.584% 	Validation Accuracy 47.965%
# Epoch: 75 	Training Loss: 0.00936191 	Validation Loss 0.01103869 	Training Accuracy 54.437% 	Validation Accuracy 47.715%
# Epoch: 76 	Training Loss: 0.00935006 	Validation Loss 0.01091384 	Training Accuracy 54.659% 	Validation Accuracy 48.216%
# Epoch: 77 	Training Loss: 0.00936911 	Validation Loss 0.01072859 	Training Accuracy 54.572% 	Validation Accuracy 48.746%
# Epoch: 78 	Training Loss: 0.00932932 	Validation Loss 0.01096971 	Training Accuracy 54.556% 	Validation Accuracy 48.439%
# Epoch: 79 	Training Loss: 0.00933609 	Validation Loss 0.01092841 	Training Accuracy 54.496% 	Validation Accuracy 49.164%
# Epoch: 80 	Training Loss: 0.00928935 	Validation Loss 0.01090767 	Training Accuracy 54.954% 	Validation Accuracy 48.021%
# Epoch: 81 	Training Loss: 0.00939329 	Validation Loss 0.01094362 	Training Accuracy 54.373% 	Validation Accuracy 48.551%
# Epoch: 82 	Training Loss: 0.00929035 	Validation Loss 0.01105803 	Training Accuracy 54.679% 	Validation Accuracy 48.105%
# Epoch: 83 	Training Loss: 0.00934998 	Validation Loss 0.01079639 	Training Accuracy 54.679% 	Validation Accuracy 48.356%
# Epoch: 84 	Training Loss: 0.00931062 	Validation Loss 0.01074812 	Training Accuracy 55.030% 	Validation Accuracy 48.300%
# Epoch: 85 	Training Loss: 0.00930750 	Validation Loss 0.01088452 	Training Accuracy 54.862% 	Validation Accuracy 48.077%
# Epoch: 86 	Training Loss: 0.00935087 	Validation Loss 0.01101528 	Training Accuracy 54.441% 	Validation Accuracy 48.272%
# Epoch: 87 	Training Loss: 0.00932948 	Validation Loss 0.01073166 	Training Accuracy 54.958% 	Validation Accuracy 48.829%
# Epoch: 88 	Training Loss: 0.00932515 	Validation Loss 0.01089743 	Training Accuracy 54.170% 	Validation Accuracy 48.662%
# Epoch: 89 	Training Loss: 0.00928386 	Validation Loss 0.01101501 	Training Accuracy 54.711% 	Validation Accuracy 49.554%
# Epoch: 90 	Training Loss: 0.00934978 	Validation Loss 0.01073686 	Training Accuracy 54.755% 	Validation Accuracy 48.941%
# Epoch: 91 	Training Loss: 0.00930589 	Validation Loss 0.01150060 	Training Accuracy 54.624% 	Validation Accuracy 47.408%
# Epoch: 92 	Training Loss: 0.00924787 	Validation Loss 0.01059012 	Training Accuracy 55.157% 	Validation Accuracy 49.136%
# Epoch: 93 	Training Loss: 0.00925838 	Validation Loss 0.01091183 	Training Accuracy 54.831% 	Validation Accuracy 48.969%
# Epoch: 94 	Training Loss: 0.00925001 	Validation Loss 0.01076170 	Training Accuracy 55.038% 	Validation Accuracy 48.718%
# Epoch: 95 	Training Loss: 0.00922537 	Validation Loss 0.01079287 	Training Accuracy 55.117% 	Validation Accuracy 48.216%
# Epoch: 96 	Training Loss: 0.00922939 	Validation Loss 0.01085868 	Training Accuracy 54.831% 	Validation Accuracy 48.746%
# Epoch: 97 	Training Loss: 0.00928614 	Validation Loss 0.01080664 	Training Accuracy 55.058% 	Validation Accuracy 48.216%
# Epoch: 98 	Training Loss: 0.00926528 	Validation Loss 0.01083555 	Training Accuracy 54.874% 	Validation Accuracy 47.687%
# Epoch: 99 	Training Loss: 0.00923785 	Validation Loss 0.01079590 	Training Accuracy 54.994% 	Validation Accuracy 49.833%
# Epoch: 100 	Training Loss: 0.00920759 	Validation Loss 0.01114873 	Training Accuracy 55.551% 	Validation Accuracy 48.328%
# ===================================Training Finished===================================

# %%
torch.save(net.state_dict(),'deep_emotion_training_by_Dame.pt')

# %%
net = Deep_Emotion()
net.load_state_dict(torch.load('deep_emotion_training_by_Dame.pt'))
net.to(device)
# Out:
# Deep_Emotion(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=810, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=7, bias=True)
#   (localization): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(7, 7), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(8, 10, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#   )
#   (fc_loc): Sequential(
#     (0): Linear(in_features=640, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=6, bias=True)
#   )
# )

# %%
import cv2
import matplotlib.pyplot as plt

# %%
frame= cv2.imread('fear1.jpg')

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = (cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

# %%
faces = faceCascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in faces:
    roi_gray=gray[y:y+h, x:x+w]
    roi_color=frame[y:y+h, x:x+w]
    cv2.rectangle(frame, (x,y), (x+w, y+h), (255, 0, 0), 2)
    facess= faceCascade.detectMultiScale(roi_gray)
    if len(facess)==0:
        print("face not detected")
    else:
        for (ex,ey,ew,eh) in facess:
            face_roi = roi_color[ey:ey+eh, ex:ex+ew]

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(face_roi)

# %%
face_roi.shape
# Out:
# (52, 52, 3)

# %%
gray = (cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY))

# %%
gray.shape
# Out:
# (52, 52)

# %%
final_image =cv2.resize(gray, (48,48))

# %%
final_image.shape
# Out:
# (48, 48)

# %%
final_image = np.expand_dims(final_image, axis=0) #need fourth dimension

# %%
final_image.shape
# Out:
# (1, 48, 48)

# %%
final_image = np.expand_dims(final_image, axis=0) #need fourth dimension

# %%
final_image.shape
# Out:
# (1, 1, 48, 48)

# %%
final_image= final_image/255.0 ##normalization step

# %%
dataa= torch.from_numpy(final_image)

# %%
dataa= dataa.type(torch.FloatTensor)

# %%
dataa= dataa.to(device)

# %%
outputs= net(dataa)
pred= F.softmax(outputs,dim=1)

# %%
print(pred)
# Out:
# tensor([[0.1254, 0.0018, 0.3220, 0.2543, 0.0947, 0.1576, 0.0442]],
#        grad_fn=<SoftmaxBackward0>)

# %%
print(torch.argmax(pred))
# Out:
# tensor(2)

# %%
index_pred=torch.argmax(pred)

# %%
if (index_pred ==5):
    print("just checking the value")

# %%
#live webcam

# %%
import cv2
path='haarcascade_frontalface_default.xml'
font_scale= 1.5
font= cv2.FONT_HERSHEY_PLAIN

#set the rectangle background to white
rectangle_bgr= (255,255,255)
#make a black image
img=np.zeros((500,500))
#set some text
text= "some text in the box!"
#gt the width and height of the text box
(text_width, text_height)=cv2.getTextSize(text, font, fontScale=font_scale, thickness=1)[0]
#set the text star position
text_offset_x= 10
text_offset_y= img.shape[0] - 25
#make the coords of the box with a small padding of two pixels 
box_coords= ((text_offset_x, text_offset_y), (text_offset_x + text_width +2, text_offset_y + text_height - 2))
cv2.rectangle(img, box_coords[0], box_coords[1], rectangle_bgr, cv2.FILLED)
cv2.putText(img, text, (text_offset_x, text_offset_y), font, fontScale=font_scale, color=(0,0,0), thickness=1)

cap =cv2.VideoCapture(1)
#check if the webcam is opened correctly
if not cap.isOpened():
    cap =cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open webcam")

while True:
    ret,frame =cap.read()
    faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray = (cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))
    faces = faceCascade.detectMultiScale(gray,1.1,4)
    for x,y,w,h in faces:
        roi_gray=gray[y:y+h, x:x+w]
        roi_color=frame[y:y+h, x:x+w]
        cv2.rectangle(frame, (x,y), (x+w, y+h), (255, 0, 0), 2)
        facess= faceCascade.detectMultiScale(roi_gray)
        if len(facess)==0:
            print("face not detected")
        else:
            for (ex,ey,ew,eh) in facess:
                face_roi = roi_color[ey:ey+eh, ex:ex+ew] #cropping the face
    graytemp= cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY)
    final_image =cv2.resize(graytemp, (48,48))
    final_image = np.expand_dims(final_image, axis=0) #need fourth dimension
    final_image = np.expand_dims(final_image, axis=0) #need fourth dimension
    final_image= final_image/255.0 ##normalization step
    dataa= torch.from_numpy(final_image)
    dataa= dataa.type(torch.FloatTensor)
    dataa= dataa.to(device)
    outputs= net(dataa)
    Pred= F.softmax(outputs,dim=1)
    Predictions=torch.argmax(Pred)
    print(Predictions)


    font= cv2.FONT_HERSHEY_SIMPLEX

    font_scale= 1.5
    font= cv2.FONT_HERSHEY_PLAIN

    if ((Predictions)==0):
        status="Angry"

        x1,y1,w1,h1 =0,0,175,75
        #Draw blaxk bacground rectangle
        cv2.rectangle(frame,(x1,x1), (x1+w1, y1+h1), (0,0,0),-1)
        #add text
        cv2.putText(frame,status, (x1+ int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status, (100, 150), font,3, (0,0,255), 2,cv2.LINE_4)

        cv2.rectangle(frame,(x,x), (x+w, y+h), (0,0,255))
    
    elif ((Predictions)==1):
        status="Disgust"

        x1,y1,w1,h1 =0,0,175,75
        #Draw blaxk bacground rectangle
        cv2.rectangle(frame,(x1,x1), (x1+w1, y1+h1), (0,0,0),-1)
        #add text
        cv2.putText(frame,status, (x1+ int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status, (100, 150), font,3, (0,0,255), 2,cv2.LINE_4)

        cv2.rectangle(frame,(x,x), (x+w, y+h), (0,0,255))
    
    elif ((Predictions)==2):
        status="Fear"

        x1,y1,w1,h1 =0,0,175,75
        #Draw blaxk bacground rectangle
        cv2.rectangle(frame,(x1,x1), (x1+w1, y1+h1), (0,0,0),-1)
        #add text
        cv2.putText(frame,status, (x1+ int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status, (100, 150), font,3, (0,0,255), 2,cv2.LINE_4)

        cv2.rectangle(frame,(x,x), (x+w, y+h), (0,0,255))

    elif ((Predictions)==3):
        status="Happy"

        x1,y1,w1,h1 =0,0,175,75
        #Draw blaxk bacground rectangle
        cv2.rectangle(frame,(x1,x1), (x1+w1, y1+h1), (0,0,0),-1)
        #add text
        cv2.putText(frame,status, (x1+ int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status, (100, 150), font,3, (0,0,255), 2,cv2.LINE_4)

        cv2.rectangle(frame,(x,x), (x+w, y+h), (0,0,255))

    elif ((Predictions)==4):
        status="Sad"

        x1,y1,w1,h1 =0,0,175,75
        #Draw blaxk bacground rectangle
        cv2.rectangle(frame,(x1,x1), (x1+w1, y1+h1), (0,0,0),-1)
        #add text
        cv2.putText(frame,status, (x1+ int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status, (100, 150), font,3, (0,0,255), 2,cv2.LINE_4)

        cv2.rectangle(frame,(x,x), (x+w, y+h), (0,0,255))

    elif ((Predictions)==5):
        status="Surprise"

        x1,y1,w1,h1 =0,0,175,75
        #Draw blaxk bacground rectangle
        cv2.rectangle(frame,(x1,x1), (x1+w1, y1+h1), (0,0,0),-1)
        #add text
        cv2.putText(frame,status, (x1+ int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status, (100, 150), font,3, (0,0,255), 2,cv2.LINE_4)

        cv2.rectangle(frame,(x,x), (x+w, y+h), (0,0,255))

    elif ((Predictions)==6):
        status="Neutral"

        x1,y1,w1,h1 =0,0,175,75
        #Draw blaxk bacground rectangle
        cv2.rectangle(frame,(x1,x1), (x1+w1, y1+h1), (0,0,0),-1)
        #add text
        cv2.putText(frame,status, (x1+ int(w1/10), y1+int(h1/2)), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,0,255), 2)
        
        cv2.putText(frame,status, (100, 150), font,3, (0,0,255), 2,cv2.LINE_4)

        cv2.rectangle(frame,(x,x), (x+w, y+h), (0,0,255))

    # Afficher la vidéo avec détection de visages et prédictions
    cv2.imshow('Emotion Detection', frame)

    # Attendre une touche pour fermer la fenêtre
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# tensor(2)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(4)
# tensor(2)
# tensor(3)
# tensor(2)
# tensor(3)
# tensor(4)
# tensor(2)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(3)
# tensor(0)
# tensor(4)
# tensor(3)
# tensor(6)
# face not detected
# tensor(4)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# face not detected
# tensor(4)
# face not detected
# tensor(4)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# tensor(4)
# face not detected
# tensor(4)
# tensor(3)
# tensor(2)
# face not detected
# tensor(4)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(0)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# tensor(2)
# face not detected
# tensor(2)
# tensor(2)
# face not detected
# tensor(2)
# tensor(2)
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(0)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# tensor(4)
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(5)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# tensor(2)
# tensor(2)
# face not detected
# tensor(0)
# tensor(2)
# face not detected
# tensor(2)
# tensor(3)
# face not detected
# tensor(3)
# tensor(2)
# tensor(4)
# face not detected
# tensor(2)
# tensor(2)
# tensor(2)
# face not detected
# tensor(2)
# tensor(0)
# tensor(2)
# tensor(2)
# face not detected
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(4)
# tensor(2)
# face not detected
# tensor(0)
# face not detected
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# face not detected
# tensor(4)
# face not detected
# tensor(0)
# face not detected
# face not detected
# tensor(4)
# tensor(0)
# face not detected
# tensor(6)
# face not detected
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(6)
# face not detected
# tensor(6)
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# face not detected
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(5)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(3)
# tensor(5)
# tensor(4)
# tensor(3)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(5)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(5)
# tensor(5)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(3)
# tensor(5)
# face not detected
# tensor(4)
# tensor(3)
# tensor(3)
# face not detected
# tensor(4)
# face not detected
# tensor(4)
# face not detected
# tensor(3)
# face not detected
# tensor(4)
# face not detected
# tensor(4)
# tensor(4)
# tensor(4)
# face not detected
# tensor(3)
# face not detected
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(4)
# face not detected
# tensor(3)
# tensor(4)
# tensor(6)
# face not detected
# tensor(3)
# face not detected
# tensor(6)
# face not detected
# tensor(3)
# tensor(6)
# face not detected
# tensor(6)
# face not detected
# tensor(3)
# face not detected
# face not detected
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# tensor(6)
# face not detected
# tensor(0)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(6)
# tensor(3)
# face not detected
# tensor(6)
# tensor(6)
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# face not detected
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(6)
# face not detected
# face not detected
# tensor(6)
# face not detected
# tensor(6)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(6)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# tensor(0)
# tensor(0)
# face not detected
# tensor(3)
# tensor(0)
# tensor(1)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(1)
# tensor(5)
# tensor(6)
# tensor(0)
# tensor(3)
# tensor(0)
# tensor(3)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(3)
# tensor(6)
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(3)
# face not detected
# tensor(4)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(3)
# tensor(1)
# tensor(3)
# tensor(0)
# tensor(1)
# tensor(6)
# tensor(0)
# tensor(6)
# tensor(3)
# tensor(0)
# tensor(6)
# tensor(3)
# face not detected
# tensor(6)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(5)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(4)
# tensor(3)
# face not detected
# tensor(4)
# tensor(4)
# tensor(4)
# tensor(2)
# tensor(4)
# face not detected
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(4)
# tensor(3)
# tensor(4)
# tensor(3)
# tensor(5)
# tensor(3)
# tensor(2)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(4)
# tensor(2)
# tensor(3)
# tensor(4)
# tensor(2)
# face not detected
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(6)
# tensor(0)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(6)
# face not detected
# tensor(3)
# tensor(6)
# face not detected
# face not detected
# tensor(0)
# face not detected
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(0)
# tensor(2)
# tensor(0)
# tensor(5)
# tensor(4)
# tensor(0)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(5)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(2)
# tensor(0)
# tensor(2)
# face not detected
# tensor(2)
# face not detected
# tensor(6)
# face not detected
# tensor(6)
# tensor(2)
# face not detected
# tensor(0)
# tensor(6)
# tensor(0)
# tensor(6)
# tensor(0)
# tensor(0)
# face not detected
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# face not detected
# tensor(0)
# tensor(4)
# tensor(5)
# face not detected
# face not detected
# tensor(6)
# face not detected
# face not detected
# tensor(6)
# face not detected
# face not detected
# tensor(0)
# face not detected
# tensor(6)
# face not detected
# tensor(0)
# tensor(0)
# tensor(0)
# face not detected
# tensor(0)
# face not detected
# tensor(5)
# face not detected
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(4)
# tensor(0)
# face not detected
# tensor(6)
# tensor(0)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(4)
# tensor(6)
# tensor(5)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(0)
# face not detected
# tensor(5)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(6)
# tensor(5)
# tensor(0)
# face not detected
# tensor(4)
# face not detected
# tensor(5)
# face not detected
# tensor(0)
# face not detected
# tensor(6)
# face not detected
# tensor(0)
# face not detected
# tensor(0)
# face not detected
# face not detected
# tensor(0)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(4)
# tensor(3)
# tensor(6)
# tensor(2)
# tensor(3)
# tensor(2)
# tensor(3)
# face not detected
# tensor(2)
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(4)
# tensor(6)
# tensor(2)
# tensor(0)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(6)
# tensor(0)
# tensor(6)
# tensor(0)
# tensor(0)
# tensor(6)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(3)
# face not detected
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(3)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(4)
# tensor(6)
# tensor(2)
# tensor(2)
# tensor(2)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# tensor(6)
# tensor(4)
# tensor(3)
# tensor(6)
# face not detected
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(3)
# tensor(4)
# tensor(6)
# tensor(6)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(5)
# face not detected
# tensor(6)
# tensor(3)
# tensor(2)
# tensor(2)
# tensor(5)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(6)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# tensor(3)
# face not detected
# tensor(0)
# face not detected
# tensor(1)
# tensor(0)
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(0)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(0)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# face not detected
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(2)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(6)
# tensor(6)
# tensor(3)
# tensor(0)
# tensor(2)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(1)
# tensor(3)
# tensor(3)
# tensor(5)
# tensor(6)
# tensor(6)
# tensor(3)
# face not detected
# tensor(0)
# face not detected
# tensor(0)
# tensor(4)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(5)
# tensor(4)
# tensor(5)
# face not detected
# tensor(4)
# face not detected
# tensor(4)
# face not detected
# tensor(5)
# face not detected
# tensor(3)
# face not detected
# tensor(5)
# face not detected
# tensor(5)
# face not detected
# tensor(5)
# tensor(3)
# face not detected
# tensor(0)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# tensor(0)
# tensor(0)
# face not detected
# tensor(4)
# face not detected
# tensor(4)
# tensor(3)
# face not detected
# tensor(0)
# face not detected
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(4)
# tensor(4)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# tensor(3)
# face not detected
# tensor(3)
# tensor(5)
# face not detected
# tensor(3)
# face not detected
# tensor(0)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# face not detected
# tensor(3)
# tensor(2)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(6)
# tensor(3)
# tensor(2)
# face not detected
# tensor(2)
# tensor(6)
# tensor(3)
# tensor(3)
# tensor(2)
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(3)
# face not detected
# tensor(6)
# face not detected
# tensor(3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[110], line 31
#      29 while True:
#      30     ret,frame =cap.read()
# ---> 31     faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#      32     gray = (cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))
#      33     faces = faceCascade.detectMultiScale(gray,1.1,4)
#
# KeyboardInterrupt:
